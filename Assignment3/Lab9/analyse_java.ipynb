# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output_folder/TypeMetrics.csv")
df
# Out:
#   Project Name             Package Name                 Type Name  LCOM1  \
# 0      problem      org.zalando.problem           GenericProblems    1.0
# 1      problem      org.zalando.problem          ThrowableProblem   10.0
# 2      problem      org.zalando.problem            DefaultProblem    1.0
# 3      problem      org.zalando.problem                   Problem   66.0
# 4      problem      org.zalando.problem  AbstractThrowableProblem   51.0
# 5      problem      org.zalando.problem            ProblemBuilder   29.0
# 6      problem      org.zalando.problem                StatusType    1.0
# 7      problem      org.zalando.problem               Exceptional    3.0
# 8      problem  org.zalando.problem.spi       StackTraceProcessor    0.0
#
#    LCOM2  LCOM3  LCOM4     LCOM5    YALCOM
# 0    0.0    2.0    2.0  0.000000  1.000000
# 1    0.0    5.0    5.0  0.000000  1.000000
# 2    0.0    2.0    2.0  0.000000  0.000000
# 3   66.0   12.0    6.0  1.000000 -1.000000
# 4    0.0    2.0    2.0  0.666667  0.133333
# 5   22.0    2.0    2.0  0.890625  0.222222
# 6    0.0    2.0    2.0  0.000000 -1.000000
# 7    0.0    3.0    2.0  0.000000 -1.000000
# 8    0.0    3.0    3.0  0.000000 -1.000000

# %%
# Create a new column 'MaxLCOM' that holds the maximum value among LCOM1 to LCOM5 for each class
df['MaxLCOM'] = df[['LCOM1', 'LCOM2', 'LCOM3', 'LCOM4', 'LCOM5']].max(axis=1)
df.sort_values("MaxLCOM", ascending=False)
# Out:
#   Project Name             Package Name                 Type Name  LCOM1  \
# 3      problem      org.zalando.problem                   Problem   66.0
# 4      problem      org.zalando.problem  AbstractThrowableProblem   51.0
# 5      problem      org.zalando.problem            ProblemBuilder   29.0
# 1      problem      org.zalando.problem          ThrowableProblem   10.0
# 7      problem      org.zalando.problem               Exceptional    3.0
# 8      problem  org.zalando.problem.spi       StackTraceProcessor    0.0
# 0      problem      org.zalando.problem           GenericProblems    1.0
# 2      problem      org.zalando.problem            DefaultProblem    1.0
# 6      problem      org.zalando.problem                StatusType    1.0
#
#    LCOM2  LCOM3  LCOM4     LCOM5    YALCOM  MaxLCOM
# 3   66.0   12.0    6.0  1.000000 -1.000000     66.0
# 4    0.0    2.0    2.0  0.666667  0.133333     51.0
# 5   22.0    2.0    2.0  0.890625  0.222222     29.0
# 1    0.0    5.0    5.0  0.000000  1.000000     10.0
# 7    0.0    3.0    2.0  0.000000 -1.000000      3.0
# 8    0.0    3.0    3.0  0.000000 -1.000000      3.0
# 0    0.0    2.0    2.0  0.000000  1.000000      2.0
# 2    0.0    2.0    2.0  0.000000  0.000000      2.0
# 6    0.0    2.0    2.0  0.000000 -1.000000      2.0
